# %% [markdown]
# <a href="https://colab.research.google.com/github/batmac/google.collab/blob/main/wizard_vicuna_13B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive
# !git clone https://github.com/oobabooga/one-click-installers
# %cd one-click-installers 
# TheBloke/wizard-vicuna-13B-GPTQ TheBloke/wizard-vicuna-13B-HF
# Out:
# /content/gdrive/MyDrive
# fatal: destination path 'one-click-installers' already exists and is not an empty directory.
# /content/gdrive/MyDrive/one-click-installers

# %%
# CMD_FLAGS='--chat --model-menu --share'
# !bash start_linux.sh
# Out:
# INFO:Gradio HTTP request redirected to localhost :)
# WARNING:The gradio "share link" feature downloads a proprietary and unaudited blob to create a reverse tunnel. This is potentially dangerous.
# bin /content/gdrive/MyDrive/one-click-installers/installer_files/env/lib/python3.10/site-packages/bitsandbytes/libbitsandbytes_cuda117.so
# The following models are available:
#
# 1. TheBloke_wizard-vicuna-13B-GPTQ
# 2. TheBloke_wizard-vicuna-13B-HF
#
# Which one do you want to load? 1-2
#
# 1
#
# INFO:Loading TheBloke_wizard-vicuna-13B-GPTQ...
# INFO:Found the following quantized model: models/TheBloke_wizard-vicuna-13B-GPTQ/wizard-vicuna-13B-GPTQ-4bit.compat.no-act-order.safetensors
# INFO:Loaded the model in 38.34 seconds.
#
# INFO:Loading the extension "gallery"...
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://a380274a14491b3b01.gradio.live
#
# ...

# %%
#%cd one-click-installers
#!du -sh one-click-installers
# !rsync -av one-click-installers /content/gdrive/MyDrive/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# one-click-installers/installer_files/env/share/gettext-0.21/its/metainfo.its
# one-click-installers/installer_files/env/share/gettext-0.21/its/metainfo.loc
# one-click-installers/installer_files/env/share/gettext/
# one-click-installers/installer_files/env/share/gettext/ABOUT-NLS
# one-click-installers/installer_files/env/share/gettext/archive.dir.tar.xz
# one-click-installers/installer_files/env/share/gettext/config.rpath
# one-click-installers/installer_files/env/share/gettext/gettext.h
# one-click-installers/installer_files/env/share/gettext/javaversion.class
# one-click-installers/installer_files/env/share/gettext/msgunfmt.tcl
# one-click-installers/installer_files/env/share/gettext/po/
# one-click-installers/installer_files/env/share/gettext/po/Makefile.in.in
# one-click-installers/installer_files/env/share/gettext/po/Makevars.template
# ...
