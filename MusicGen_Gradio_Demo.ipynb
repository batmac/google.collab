# %% [markdown]
# <a href="https://colab.research.google.com/github/batmac/google.colab/blob/main/MusicGen_Gradio_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Adapted from https://github.com/camenduru/MusicGen-colab
# %cd /content
# !git clone https://github.com/facebookresearch/audiocraft
# %cd /content/audiocraft
# !pip install -r requirements.txt
# Click on the gradio link that appear.
# !python app.py --share
# See also https://colab.research.google.com/drive/1fxGqfg96RBUvGxZ1XXN07s3DthrKUl4-?usp=sharing
# for a Colab demo using the underlying API instead.
# Out:
# /content
# Cloning into 'audiocraft'...
# remote: Enumerating objects: 297, done.
# remote: Counting objects: 100% (87/87), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 297 (delta 78), reused 62 (delta 62), pack-reused 210
# Receiving objects: 100% (297/297), 634.89 KiB | 16.71 MiB/s, done.
# Resolving deltas: 100% (150/150), done.
# /content/audiocraft
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting av (from -r requirements.txt (line 2))
#   Downloading av-10.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 33.0 MB/s eta 0:00:00
# Collecting einops (from -r requirements.txt (line 3))
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.3 MB/s eta 0:00:00
# Collecting flashy>=0.0.1 (from -r requirements.txt (line 4))
#   Downloading flashy-0.0.2.tar.gz (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 6.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting hydra-core>=1.1 (from -r requirements.txt (line 5))
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 22.3 MB/s eta 0:00:00
# Collecting hydra_colorlog (from -r requirements.txt (line 6))
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl (3.6 kB)
# Collecting julius (from -r requirements.txt (line 7))
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 9.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting num2words (from -r requirements.txt (line 8))
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (1.22.4)
# Collecting sentencepiece (from -r requirements.txt (line 10))
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy==3.5.2 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 11)) (3.5.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 12)) (2.0.1+cu118)
# Requirement already satisfied: torchaudio>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 13)) (2.0.2+cu118)
# Collecting huggingface_hub (from -r requirements.txt (line 14))
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 33.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 15)) (4.65.0)
# Collecting transformers (from -r requirements.txt (line 16))
#   Downloading transformers-4.30.1-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 107.0 MB/s eta 0:00:00
# Collecting xformers (from -r requirements.txt (line 17))
#   Downloading xformers-0.0.20-cp310-cp310-manylinux2014_x86_64.whl (109.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 1.8 MB/s eta 0:00:00
# Collecting demucs (from -r requirements.txt (line 18))
#   Downloading demucs-4.0.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 88.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 19)) (0.10.0.post2)
# Collecting gradio (from -r requirements.txt (line 20))
#   Downloading gradio-3.34.0-py3-none-any.whl (20.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 95.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (6.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.5.2->-r requirements.txt (line 11)) (3.3.0)
# Collecting dora-search (from flashy>=0.0.1->-r requirements.txt (line 4))
#   Downloading dora_search-0.1.12.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 12.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting colorlog (from flashy>=0.0.1->-r requirements.txt (line 4))
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.1->-r requirements.txt (line 5))
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.8 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->-r requirements.txt (line 5))
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting docopt>=0.6.2 (from num2words->-r requirements.txt (line 8))
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->-r requirements.txt (line 12)) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->-r requirements.txt (line 12)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->-r requirements.txt (line 12)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->-r requirements.txt (line 12)) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->-r requirements.txt (line 12)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->-r requirements.txt (line 12)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->-r requirements.txt (line 12)) (16.0.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r requirements.txt (line 14)) (2023.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->-r requirements.txt (line 14)) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r requirements.txt (line 16)) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->-r requirements.txt (line 16))
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 86.6 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->-r requirements.txt (line 16))
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.2 MB/s eta 0:00:00
# Collecting pyre-extensions==0.0.29 (from xformers->-r requirements.txt (line 17))
#   Downloading pyre_extensions-0.0.29-py3-none-any.whl (12 kB)
# Collecting typing-inspect (from pyre-extensions==0.0.29->xformers->-r requirements.txt (line 17))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting diffq>=0.2.1 (from demucs->-r requirements.txt (line 18))
#   Downloading diffq-0.2.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (418 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.8/418.8 kB 47.1 MB/s eta 0:00:00
# Collecting lameenc>=1.2 (from demucs->-r requirements.txt (line 18))
#   Downloading lameenc-1.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 14.7 MB/s eta 0:00:00
# Collecting openunmix (from demucs->-r requirements.txt (line 18))
#   Downloading openunmix-1.2.1-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.7/46.7 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (3.0.0)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (0.56.4)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (0.12.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (0.3.5)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->-r requirements.txt (line 19)) (1.0.5)
# Collecting aiofiles (from gradio->-r requirements.txt (line 20))
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting aiohttp (from gradio->-r requirements.txt (line 20))
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 75.9 MB/s eta 0:00:00
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r requirements.txt (line 20)) (4.2.2)
# Collecting fastapi (from gradio->-r requirements.txt (line 20))
#   Downloading fastapi-0.97.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 7.9 MB/s eta 0:00:00
# Collecting ffmpy (from gradio->-r requirements.txt (line 20))
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client>=0.2.6 (from gradio->-r requirements.txt (line 20))
#   Downloading gradio_client-0.2.6-py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.3/288.3 kB 35.7 MB/s eta 0:00:00
# Collecting httpx (from gradio->-r requirements.txt (line 20))
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r requirements.txt (line 20)) (2.2.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.10/dist-packages (from gradio->-r requirements.txt (line 20)) (2.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from gradio->-r requirements.txt (line 20)) (3.7.1)
# Collecting mdit-py-plugins<=0.3.3 (from gradio->-r requirements.txt (line 20))
#   Downloading mdit_py_plugins-0.3.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 7.4 MB/s eta 0:00:00
# Collecting orjson (from gradio->-r requirements.txt (line 20))
#   Downloading orjson-3.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from gradio->-r requirements.txt (line 20)) (1.5.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from gradio->-r requirements.txt (line 20)) (8.4.0)
# Collecting pydub (from gradio->-r requirements.txt (line 20))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: pygments>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio->-r requirements.txt (line 20)) (2.14.0)
# Collecting python-multipart (from gradio->-r requirements.txt (line 20))
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 2.7 MB/s eta 0:00:00
# Collecting semantic-version (from gradio->-r requirements.txt (line 20))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting uvicorn>=0.14.0 (from gradio->-r requirements.txt (line 20))
#   Downloading uvicorn-0.22.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.0 MB/s eta 0:00:00
# Collecting websockets>=10.0 (from gradio->-r requirements.txt (line 20))
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair>=4.2.0->gradio->-r requirements.txt (line 20)) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair>=4.2.0->gradio->-r requirements.txt (line 20)) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair>=4.2.0->gradio->-r requirements.txt (line 20)) (0.12.0)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from diffq>=0.2.1->demucs->-r requirements.txt (line 18)) (0.29.34)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio->-r requirements.txt (line 20)) (0.1.2)
# Collecting linkify-it-py<3,>=1 (from markdown-it-py[linkify]>=2.0.0->gradio->-r requirements.txt (line 20))
#   Downloading linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->-r requirements.txt (line 19)) (0.39.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->gradio->-r requirements.txt (line 20)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->gradio->-r requirements.txt (line 20)) (2022.7.1)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from pooch<1.7,>=1.0->librosa->-r requirements.txt (line 19)) (1.4.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->-r requirements.txt (line 11)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->-r requirements.txt (line 11)) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->-r requirements.txt (line 11)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.5.2->-r requirements.txt (line 11)) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa->-r requirements.txt (line 19)) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa->-r requirements.txt (line 19)) (1.15.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.2->-r requirements.txt (line 11)) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy==3.5.2->-r requirements.txt (line 11)) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy==3.5.2->-r requirements.txt (line 11)) (8.1.3)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio->-r requirements.txt (line 20))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio->-r requirements.txt (line 20)) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->gradio->-r requirements.txt (line 20))
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->gradio->-r requirements.txt (line 20))
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->gradio->-r requirements.txt (line 20))
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.6 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->gradio->-r requirements.txt (line 20))
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 19.4 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->gradio->-r requirements.txt (line 20))
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting retrying (from dora-search->flashy>=0.0.1->-r requirements.txt (line 4))
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting submitit (from dora-search->flashy>=0.0.1->-r requirements.txt (line 4))
#   Downloading submitit-1.4.5-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 10.3 MB/s eta 0:00:00
# Collecting treetable (from dora-search->flashy>=0.0.1->-r requirements.txt (line 4))
#   Downloading treetable-0.2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi->gradio->-r requirements.txt (line 20))
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 3.4 MB/s eta 0:00:00
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx->gradio->-r requirements.txt (line 20))
#   Downloading httpcore-0.17.2-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio->-r requirements.txt (line 20)) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio->-r requirements.txt (line 20)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio->-r requirements.txt (line 20)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio->-r requirements.txt (line 20)) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio->-r requirements.txt (line 20)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio->-r requirements.txt (line 20)) (3.0.9)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.0->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->-r requirements.txt (line 19)) (2.21)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->gradio->-r requirements.txt (line 20)) (3.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio->-r requirements.txt (line 20)) (0.19.3)
# Collecting uc-micro-py (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio->-r requirements.txt (line 20))
#   Downloading uc_micro_py-1.0.2-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->gradio->-r requirements.txt (line 20)) (1.16.0)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from submitit->dora-search->flashy>=0.0.1->-r requirements.txt (line 4)) (2.2.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect->pyre-extensions==0.0.29->xformers->-r requirements.txt (line 17))
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Building wheels for collected packages: flashy, antlr4-python3-runtime, julius, demucs, docopt, dora-search, ffmpy, treetable
#   Building wheel for flashy (pyproject.toml) ... done
#   Created wheel for flashy: filename=flashy-0.0.2-py3-none-any.whl size=34527 sha256=13c1b8c4153da0a848faf2ed13d8c2910e1da28cf7956415318e22db08051aaa
#   Stored in directory: /root/.cache/pip/wheels/07/bd/3d/16c6bc059203299f37b6014643b739afb7f6d1be13a94fc2f7
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=e0d67c70d76a9370ae35ada58f2e1b63a7d0c04ba1baa773e0f46211aa0fd2ce
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21878 sha256=06e1247fd778efd3853199e8cfccd55012b62a9bcedc15423b1017d523716ed6
#   Stored in directory: /root/.cache/pip/wheels/b9/b2/05/f883527ffcb7f2ead5438a2c23439aa0c881eaa9a4c80256f4
#   Building wheel for demucs (setup.py) ... done
#   Created wheel for demucs: filename=demucs-4.0.0-py3-none-any.whl size=76505 sha256=9cf8596ccbe70b3e406cee7b8334e1c3b46e2c315a6c70cbeb18c741ad508c6f
#   Stored in directory: /root/.cache/pip/wheels/64/fc/2e/a8e874bba1518a336f21a94085013fba17cb86658ce18ec1c7
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=a40e8f9a84d2df66bcfbb70a2f146bda9072894bed3c9e8af2385e8e2c44cbc3
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for dora-search (pyproject.toml) ... done
#   Created wheel for dora-search: filename=dora_search-0.1.12-py3-none-any.whl size=75090 sha256=120dcc8038d4e4204f79f5f018dd61553b6b17e678e901fa3f22f911465e8121
#   Stored in directory: /root/.cache/pip/wheels/b1/c2/c0/bea5cc405497284d584b958f293ef32c23bad42ae5e44d973c
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4694 sha256=03f9ee7f99882e33551d10a0ffaa330b2ce8fd4023b5e4c42fc6aa7e8a033160
#   Stored in directory: /root/.cache/pip/wheels/0c/c2/0e/3b9c6845c6a4e35beb90910cc70d9ac9ab5d47402bd62af0df
#   Building wheel for treetable (setup.py) ... done
#   Created wheel for treetable: filename=treetable-0.2.5-py3-none-any.whl size=7332 sha256=2735a17b70d4552dc386e692b476bb2142e58182230a3f8b0078ae92059d0744
#   Stored in directory: /root/.cache/pip/wheels/72/55/0e/91c3655bdb162446f8a7cd477579397544454a63ae7c599c0c
# Successfully built flashy antlr4-python3-runtime julius demucs docopt dora-search ffmpy treetable
# Installing collected packages: tokenizers, sentencepiece, safetensors, pydub, lameenc, ffmpy, docopt, av, antlr4-python3-runtime, websockets, uc-micro-py, treetable, submitit, semantic-version, retrying, python-multipart, orjson, omegaconf, num2words, mypy-extensions, multidict, h11, frozenlist, einops, colorlog, async-timeout, aiofiles, yarl, uvicorn, typing-inspect, starlette, mdit-py-plugins, linkify-it-py, hydra-core, huggingface_hub, httpcore, aiosignal, transformers, pyre-extensions, hydra_colorlog, httpx, fastapi, aiohttp, gradio-client, gradio, openunmix, julius, dora-search, diffq, xformers, flashy, demucs
# Successfully installed aiofiles-23.1.0 aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 async-timeout-4.0.2 av-10.0.0 colorlog-6.7.0 demucs-4.0.0 diffq-0.2.4 docopt-0.6.2 dora-search-0.1.12 einops-0.6.1 fastapi-0.97.0 ffmpy-0.3.0 flashy-0.0.2 frozenlist-1.3.3 gradio-3.34.0 gradio-client-0.2.6 h11-0.14.0 httpcore-0.17.2 httpx-0.24.1 huggingface_hub-0.15.1 hydra-core-1.3.2 hydra_colorlog-1.2.0 julius-0.2.7 lameenc-1.4.2 linkify-it-py-2.0.2 mdit-py-plugins-0.3.3 multidict-6.0.4 mypy-extensions-1.0.0 num2words-0.5.12 omegaconf-2.3.0 openunmix-1.2.1 orjson-3.9.1 pydub-0.25.1 pyre-extensions-0.0.29 python-multipart-0.0.6 retrying-1.3.4 safetensors-0.3.1 semantic-version-2.10.0 sentencepiece-0.1.99 starlette-0.27.0 submitit-1.4.5 tokenizers-0.13.3 transformers-4.30.1 treetable-0.2.5 typing-inspect-0.9.0 uc-micro-py-1.0.2 uvicorn-0.22.0 websockets-11.0.3 xformers-0.0.20 yarl-1.9.2
# 2023-06-12 09:57:50.161136: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-12 09:57:51.439028: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-12 09:57:55.562460: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-12 09:57:55.563059: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-12 09:57:55.563250: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://d52f5d9d667eb1d6fa.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Loading model melody
# Downloading (…)ssion_state_dict.bin: 100% 236M/236M [00:00<00:00, 368MB/s]
# Downloading state_dict.bin: 100% 2.77G/2.77G [00:13<00:00, 212MB/s]
# Downloading: "https://dl.fbaipublicfiles.com/demucs/hybrid_transformer/955717e8-8726e21a.th" to /root/.cache/torch/hub/checkpoints/955717e8-8726e21a.th
# 100% 80.2M/80.2M [00:00<00:00, 165MB/s]
# Downloading (…)ve/main/spiece.model: 100% 792k/792k [00:00<00:00, 73.7MB/s]
# Downloading (…)lve/main/config.json: 100% 1.21k/1.21k [00:00<00:00, 9.60MB/s]
# Downloading model.safetensors: 100% 892M/892M [00:03<00:00, 289MB/s]
# torch.Size([1, 2, 442368])
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py:2229: RuntimeWarning: overflow encountered in short_scalars
#   dx = [convert(x0 + ddx) - x for ddx in dx]
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py:739: RuntimeWarning: overflow encountered in short_scalars
#   y1 = self.convert_yunits(self._y0 + self._height)
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, png_pipe, from '/tmp/tmplzoybv48.png':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 1000x200, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from '/tmp/tmp349byrjy.wav':
#   Duration: 00:00:10.00, bitrate: 512 kb/s
#     Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x562212262b80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562212262b80] profile High, level 3.0
# [libx264 @ 0x562212262b80] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmp7nu8fxv2.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p(progressive), 1000x200, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 32000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 aac
# frame=  250 fps=176 q=-1.0 Lsize=     126kB time=00:00:10.01 bitrate= 102.8kbits/s speed=7.07x
# video:32kB audio:85kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 7.255618%
# [libx264 @ 0x562212262b80] frame I:1     Avg QP:22.72  size:  6710
# [libx264 @ 0x562212262b80] frame P:132   Avg QP:23.26  size:   151
# [libx264 @ 0x562212262b80] frame B:117   Avg QP:19.09  size:    47
# [libx264 @ 0x562212262b80] consecutive B-frames: 26.4% 18.4% 45.6%  9.6%
# [libx264 @ 0x562212262b80] mb I  I16..4: 53.4% 26.4% 20.3%
# [libx264 @ 0x562212262b80] mb P  I16..4:  1.4%  0.4%  0.1%  P16..4:  2.5%  0.3%  0.1%  0.0%  0.0%    skip:95.3%
# [libx264 @ 0x562212262b80] mb B  I16..4:  0.2%  0.0%  0.0%  B16..8:  2.6%  0.2%  0.0%  direct: 0.0%  skip:97.0%  L0:53.0% L1:46.3% BI: 0.7%
# [libx264 @ 0x562212262b80] 8x8 transform intra:21.6% inter:45.5%
# [libx264 @ 0x562212262b80] coded y,uvDC,uvAC intra: 3.6% 12.7% 9.4% inter: 0.1% 0.2% 0.1%
# [libx264 @ 0x562212262b80] i16 v,h,dc,p: 96%  1%  3%  0%
# [libx264 @ 0x562212262b80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18%  4% 75%  2%  0%  0%  0%  0%  0%
# [libx264 @ 0x562212262b80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 68% 18% 10%  0%  1%  1%  1%  1%  0%
# [libx264 @ 0x562212262b80] i8c dc,h,v,p: 28%  4% 68%  0%
# [libx264 @ 0x562212262b80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x562212262b80] ref P L0: 90.7%  0.4%  6.2%  2.7%
# [libx264 @ 0x562212262b80] ref B L0: 80.6% 11.5%  7.9%
# [libx264 @ 0x562212262b80] ref B L1: 99.2%  0.8%
# [libx264 @ 0x562212262b80] kb/s:25.69
# [aac @ 0x562212263f00] Qavg: 119.289
# torch.Size([1, 2, 320000])
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py:2229: RuntimeWarning: overflow encountered in short_scalars
#   dx = [convert(x0 + ddx) - x for ddx in dx]
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py:739: RuntimeWarning: overflow encountered in short_scalars
#   y1 = self.convert_yunits(self._y0 + self._height)
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, png_pipe, from '/tmp/tmp6sbalcgx.png':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 1000x200, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from '/tmp/tmpzg3gb5cs.wav':
#   Duration: 00:00:10.00, bitrate: 512 kb/s
#     Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5580889e9480] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5580889e9480] profile High, level 3.0
# [libx264 @ 0x5580889e9480] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmpboika69y.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p(progressive), 1000x200, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 32000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 aac
# frame=  250 fps=184 q=-1.0 Lsize=     125kB time=00:00:10.01 bitrate= 102.5kbits/s speed=7.36x
# video:32kB audio:85kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 7.276481%
# [libx264 @ 0x5580889e9480] frame I:1     Avg QP:22.00  size:  6540
# [libx264 @ 0x5580889e9480] frame P:135   Avg QP:23.43  size:   146
# [libx264 @ 0x5580889e9480] frame B:114   Avg QP:18.43  size:    48
# [libx264 @ 0x5580889e9480] consecutive B-frames: 27.6% 19.2% 46.8%  6.4%
# [libx264 @ 0x5580889e9480] mb I  I16..4: 60.3% 19.3% 20.4%
# [libx264 @ 0x5580889e9480] mb P  I16..4:  1.4%  0.3%  0.1%  P16..4:  1.9%  0.3%  0.1%  0.0%  0.0%    skip:96.0%
# [libx264 @ 0x5580889e9480] mb B  I16..4:  0.2%  0.0%  0.0%  B16..8:  2.9%  0.1%  0.0%  direct: 0.0%  skip:96.8%  L0:51.4% L1:48.0% BI: 0.6%
# [libx264 @ 0x5580889e9480] 8x8 transform intra:17.8% inter:43.6%
# [libx264 @ 0x5580889e9480] coded y,uvDC,uvAC intra: 3.9% 12.8% 9.6% inter: 0.1% 0.2% 0.1%
# [libx264 @ 0x5580889e9480] i16 v,h,dc,p: 95%  2%  3%  0%
# [libx264 @ 0x5580889e9480] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14%  4% 80%  2%  0%  0%  0%  0%  0%
# [libx264 @ 0x5580889e9480] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 63% 18% 14%  1%  1%  1%  1%  1%  0%
# [libx264 @ 0x5580889e9480] i8c dc,h,v,p: 27%  4% 69%  0%
# [libx264 @ 0x5580889e9480] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5580889e9480] ref P L0: 89.2%  0.8%  6.3%  3.6%
# [libx264 @ 0x5580889e9480] ref B L0: 78.3% 12.3%  9.4%
# [libx264 @ 0x5580889e9480] ref B L1: 99.6%  0.4%
# [libx264 @ 0x5580889e9480] kb/s:25.40
# [aac @ 0x5580889ea800] Qavg: 119.297
# torch.Size([1, 2, 320000])
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py:2229: RuntimeWarning: overflow encountered in short_scalars
#   dx = [convert(x0 + ddx) - x for ddx in dx]
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py:739: RuntimeWarning: overflow encountered in short_scalars
#   y1 = self.convert_yunits(self._y0 + self._height)
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, png_pipe, from '/tmp/tmp84hr_wkr.png':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 1000x200, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from '/tmp/tmp_gpqxvp5.wav':
#   Duration: 00:00:20.70, bitrate: 512 kb/s
#     Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x561c92cb8b80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x561c92cb8b80] profile High, level 3.0
# [libx264 @ 0x561c92cb8b80] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmp8d_hs4wn.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p(progressive), 1000x200, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 32000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 aac
# frame=  518 fps=102 q=-1.0 Lsize=     258kB time=00:00:20.70 bitrate= 101.9kbits/s speed=4.06x
# video:66kB audio:176kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.654482%
# [libx264 @ 0x561c92cb8b80] frame I:3     Avg QP:17.62  size:  6419
# [libx264 @ 0x561c92cb8b80] frame P:289   Avg QP:22.83  size:   132
# [libx264 @ 0x561c92cb8b80] frame B:226   Avg QP:17.48  size:    42
# [libx264 @ 0x561c92cb8b80] consecutive B-frames: 33.0% 22.8% 11.0% 33.2%
# [libx264 @ 0x561c92cb8b80] mb I  I16..4: 74.0%  6.1% 19.8%
# [libx264 @ 0x561c92cb8b80] mb P  I16..4:  1.1%  0.4%  0.0%  P16..4:  4.6%  0.2%  0.1%  0.0%  0.0%    skip:93.6%
# [libx264 @ 0x561c92cb8b80] mb B  I16..4:  0.2%  0.0%  0.0%  B16..8:  1.8%  0.2%  0.0%  direct: 0.0%  skip:97.8%  L0:41.3% L1:58.2% BI: 0.5%
# [libx264 @ 0x561c92cb8b80] 8x8 transform intra:17.6% inter:44.9%
# [libx264 @ 0x561c92cb8b80] coded y,uvDC,uvAC intra: 4.4% 12.2% 10.3% inter: 0.1% 0.1% 0.1%
# [libx264 @ 0x561c92cb8b80] i16 v,h,dc,p: 94%  2%  4%  0%
# [libx264 @ 0x561c92cb8b80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7%  2% 90%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x561c92cb8b80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 64% 18% 13%  0%  1%  1%  1%  1%  0%
# [libx264 @ 0x561c92cb8b80] i8c dc,h,v,p: 26%  4% 69%  1%
# [libx264 @ 0x561c92cb8b80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x561c92cb8b80] ref P L0: 94.8%  0.3%  3.9%  1.1%
# [libx264 @ 0x561c92cb8b80] ref B L0: 82.6% 14.9%  2.5%
# [libx264 @ 0x561c92cb8b80] ref B L1: 98.8%  1.2%
# [libx264 @ 0x561c92cb8b80] kb/s:25.81
# [aac @ 0x561c92cb9f00] Qavg: 115.287
# Loading model medium
# Downloading (…)ssion_state_dict.bin: 100% 236M/236M [00:05<00:00, 45.0MB/s]
# Downloading state_dict.bin: 100% 3.68G/3.68G [00:26<00:00, 141MB/s]
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py:2229: RuntimeWarning: overflow encountered in short_scalars
#   dx = [convert(x0 + ddx) - x for ddx in dx]
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py:739: RuntimeWarning: overflow encountered in short_scalars
#   y1 = self.convert_yunits(self._y0 + self._height)
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, png_pipe, from '/tmp/tmpiujcw0_n.png':
#   Duration: N/A, bitrate: N/A
#     Stream #0:0: Video: png, rgba(pc), 1000x200, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Guessed Channel Layout for Input Stream #1.0 : mono
# Input #1, wav, from '/tmp/tmpnc58kwc3.wav':
#   Duration: 00:00:20.70, bitrate: 512 kb/s
#     Stream #1:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 32000 Hz, mono, s16, 512 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
#   Stream #1:0 -> #0:1 (pcm_s16le (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x558694a08a40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x558694a08a40] profile High, level 3.0
# [libx264 @ 0x558694a08a40] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmp0jj3zsfb.mp4':
#   Metadata:
#     encoder         : Lavf58.29.100
#     Stream #0:0: Video: h264 (libx264) (avc1 / 0x31637661), yuv420p(progressive), 1000x200, q=-1--1, 25 fps, 12800 tbn, 25 tbc
#     Metadata:
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
#     Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 32000 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 aac
# frame=  518 fps=199 q=-1.0 Lsize=     252kB time=00:00:20.70 bitrate=  99.8kbits/s speed=7.93x
# video:61kB audio:176kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.730356%
# [libx264 @ 0x558694a08a40] frame I:3     Avg QP:20.96  size:  6349
# [libx264 @ 0x558694a08a40] frame P:316   Avg QP:23.83  size:   111
# [libx264 @ 0x558694a08a40] frame B:199   Avg QP:17.14  size:    38
# [libx264 @ 0x558694a08a40] consecutive B-frames: 39.8% 23.9%  9.3% 27.0%
# [libx264 @ 0x558694a08a40] mb I  I16..4: 74.0%  6.6% 19.4%
# [libx264 @ 0x558694a08a40] mb P  I16..4:  1.1%  0.1%  0.0%  P16..4:  1.7%  0.2%  0.1%  0.0%  0.0%    skip:96.7%
# [libx264 @ 0x558694a08a40] mb B  I16..4:  0.1%  0.0%  0.0%  B16..8:  1.6%  0.1%  0.0%  direct: 0.0%  skip:98.1%  L0:38.5% L1:60.7% BI: 0.8%
# [libx264 @ 0x558694a08a40] 8x8 transform intra:9.9% inter:39.2%
# [libx264 @ 0x558694a08a40] coded y,uvDC,uvAC intra: 4.9% 13.6% 11.5% inter: 0.1% 0.1% 0.1%
# [libx264 @ 0x558694a08a40] i16 v,h,dc,p: 94%  1%  5%  0%
# [libx264 @ 0x558694a08a40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16%  2% 80%  2%  0%  0%  0%  0%  0%
# [libx264 @ 0x558694a08a40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 67% 17% 12%  0%  1%  2%  1%  1%  1%
# [libx264 @ 0x558694a08a40] i8c dc,h,v,p: 15%  5% 79%  0%
# [libx264 @ 0x558694a08a40] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x558694a08a40] ref P L0: 92.2%  0.5%  5.3%  2.1%
# [libx264 @ 0x558694a08a40] ref B L0: 80.9% 15.9%  3.2%
# [libx264 @ 0x558694a08a40] ref B L1: 99.1%  0.9%
# [libx264 @ 0x558694a08a40] kb/s:23.74
# [aac @ 0x558694a0a000] Qavg: 127.301
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://d52f5d9d667eb1d6fa.gradio.live
