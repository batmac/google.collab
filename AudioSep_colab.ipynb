# %% [markdown]
# <a href="https://colab.research.google.com/github/batmac/google.colab/blob/main/AudioSep_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/AudioSep-hf
# %cd /content/AudioSep-hf

# !pip install -q gradio lightning torchlibrosa transformers ftfy braceexpand webdataset wget

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/AudioSep/resolve/main/audiosep_base_4M_steps.ckpt -d /content/AudioSep-hf/checkpoint -o audiosep_base_4M_steps.ckpt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/AudioSep/resolve/main/music_speech_audioset_epoch_15_esc_89.98.pt -d /content/AudioSep-hf/checkpoint -o music_speech_audioset_epoch_15_esc_89.98.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/AudioSep/resolve/main/bpe_simple_vocab_16e6.txt.gz -d /content/AudioSep-hf/models/CLAP/open_clip -o bpe_simple_vocab_16e6.txt.gz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/audo/AudioSep/resolve/main/audioset_textmap.npy -d /content/AudioSep-hf/models/CLAP/training -o audioset_textmap.npy

# !python app.py
# Out:
# /content
# Cloning into 'AudioSep-hf'...
# remote: Enumerating objects: 141, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 141 (delta 49), reused 131 (delta 45), pack-reused 0
# Receiving objects: 100% (141/141), 2.34 MiB | 5.93 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# Downloading checkpoint/audiosep_base_4M_steps.ckpt (1.3 GB)
# Error downloading object: checkpoint/audiosep_base_4M_steps.ckpt (f8cda01): Smudge error: Error downloading checkpoint/audiosep_base_4M_steps.ckpt (f8cda01bfd0ebd141eef45d41db7a3ada23a56568465840d3cff04b8010ce82c): [f8cda01bfd0ebd141eef45d41db7a3ada23a56568465840d3cff04b8010ce82c] Object does not exist on the server: [404] Object does not exist on the server
#
# Errors logged to /content/AudioSep-hf/.git/lfs/logs/20231013T192237.79540702.log
# Use `git lfs logs last` to view the log.
# error: external filter 'git-lfs filter-process' failed
# fatal: checkpoint/audiosep_base_4M_steps.ckpt: smudge filter lfs failed
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
# /content/AudioSep-hf
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 57.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 75.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 97.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 26.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 28.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.7/138.7 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 69.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.6/774.6 kB 68.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 104.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 85.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 37.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 11.4 MB/s eta 0:00:00
#   Building wheel for wget (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 18 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 120875 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.2) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4afcac|OK  |   228MiB/s|/content/AudioSep-hf/checkpoint/audiosep_base_4M_steps.ckpt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0e568c|OK  |   242MiB/s|/content/AudioSep-hf/checkpoint/music_speech_audioset_epoch_15_esc_89.98.pt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a0aff2|OK  |    26MiB/s|/content/AudioSep-hf/models/CLAP/open_clip/bpe_simple_vocab_16e6.txt.gz
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ff6b95|OK  |   5.0MiB/s|/content/AudioSep-hf/models/CLAP/training/audioset_textmap.npy
#
# Status Legend:
# (OK):download completed.
# Downloading (…)olve/main/vocab.json: 100% 899k/899k [00:00<00:00, 4.58MB/s]
# Downloading (…)olve/main/merges.txt: 100% 456k/456k [00:00<00:00, 7.11MB/s]
# Downloading (…)/main/tokenizer.json: 100% 1.36M/1.36M [00:00<00:00, 20.3MB/s]
# Downloading (…)lve/main/config.json: 100% 481/481 [00:00<00:00, 2.87MB/s]
# Downloading model.safetensors: 100% 499M/499M [00:05<00:00, 93.8MB/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/lightning/pytorch/core/saving.py:177: Found keys that are not in the model state dict but in the checkpoint: ['query_encoder.model.text_branch.embeddings.position_ids']
# Load AudioSep model from [checkpoint/audiosep_base_4M_steps.ckpt]
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://13decf575f5e139b32.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Separate audio from [/tmp/gradio/2f5641dae71a34e55da82616fd55cd71e52bedf1/acoustic_guitar-0-100.wav] with textual query [acoustic guitar]
# Separate audio from [/tmp/gradio/7931b493a0b3325ffad22a15b1d17c723b16831d/noisy_speech-0-100.wav] with textual query [speech]
# Separate audio from [/tmp/gradio/a8e265f54cbe10bad0928584490cdc3352001b5f/ticktok_piano-0-100.wav] with textual query [A ticktock sound playing at the same rhythm with piano.]
# Separate audio from [/tmp/gradio/a8e265f54cbe10bad0928584490cdc3352001b5f/ticktok_piano-0-100.wav] with textual query [drums]
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2366, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/AudioSep-hf/app.py", line 82, in <module>
#     demo.queue().launch(share=True)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2271, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 2370, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.10/dist-packages/gradio/networking.py", line 75, in close
#     self.thread.join()
#   File "/usr/lib/python3.10/threading.py", line 1096, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7860 <> https://13decf575f5e139b32.gradio.live
# ^C
